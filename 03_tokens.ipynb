# %% [markdown]
# <a href="https://colab.research.google.com/github/jayx003/GenAI-Practice/blob/main/03_tokens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://platform.openai.com/tokenizer

# %% [markdown]
# This code converts your sentence into the tokens that the GPT model uses internally.
# You are preparing it the same way the model does before generating output.

# %% [markdown]
# ## Tokenizing with code

# %%
# %pip install tiktoken

# %% [markdown]
# ### What are Tokens?
# A **token** is a small unit of text (a word or part of a word). Every prompt and response uses tokens, which affects:
# - **Cost**: You pay per token used
# - **Speed**: Fewer tokens = faster response
# - **Quality**: Sometimes shorter responses are better, sometimes you need more detail

# %% [markdown]
# ## How Are Tokens Calculated? (Using OpenAI's Token Calculator)
#
# Let's use `tiktoken` - OpenAI's official token counter - to see exactly how text is tokenized.

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

tokens = encoding.encode("Hello! My Name is Jay")

# %%
tokens
# Out:
# [9906, 0, 3092, 4076, 374, 19455]

# %%
len("Hi my name is Jay and I like Coffe".split())
# Out:
# 9

# %%
encoding = tiktoken.encoding_for_model("gpt-4o-mini")

tokens = encoding.encode("Hi my name is Jay and I like coffe")

# %%
tokens
# Out:
# [12194, 922, 1308, 382, 33342, 326, 357, 1299, 11419, 68]

# %%
len(tokens)
# Out:
# 10

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12194 = Hi
# 922 =  my
# 1308 =  name
# 382 =  is
# 33342 =  Jay
# 326 =  and
# 357 =  I
# 1299 =  like
# 11419 =  coff
# 68 = e
