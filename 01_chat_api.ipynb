# %% [markdown]
# <a href="https://colab.research.google.com/github/jayx003/GenAI-Practice/blob/main/01_chat_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **How to access API KEY or secrets**

# %%
# approach number 1 in colab
from google.colab import userdata
userdata.get('GEMINI_API_KEY')[-4:]
# Out:
# 'J2vw'

# %%
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path='./.env')

key2 = os.getenv('GEMINI_API_KEY')
key2[-4:]
# Out:
# 'J2vw'

# %% [markdown]
# **Assignment: Try to access API key using config.ini file**

# %% [markdown]
# **----------------------------------------------**

# %%
# %pip install google-genai

# %%
from google import genai
import os
from dotenv import load_dotenv

# Load .env file from parent directory
load_dotenv(dotenv_path='./.env')

API_KEY = os.getenv("GEMINI_API_KEY")

client = genai.Client(api_key=API_KEY)

response = client.models.generate_content(
    model='gemini-3.5-flash-lite',
    contents=input('Ask a que.'),
)
print(response.text)
# Out:
# Ask a que.Hello! explain about yourself in one line
# I am a large language model, trained by Google, designed to help you by answering questions, generating content, and solving problems.
